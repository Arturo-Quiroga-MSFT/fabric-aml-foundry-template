# %% [markdown]
# # 01a — Copy Fabric/OneLake table into AML as a versioned data asset
#
# Per the 6 May 2026 sync, the POC pattern is **copy** Fabric data into AML (datastore + MLTable) so AML can track lineage and versions — not direct in-place reads.
#
# Run after `00-fabric-onelake-connectivity.ipynb` confirms access.

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))

from src.copy_fabric_to_aml import copy_fabric_table_to_aml

asset_uri = copy_fabric_table_to_aml(asset_name='contoso-poc-dataset')
print('Use this URI in training:', asset_uri)
